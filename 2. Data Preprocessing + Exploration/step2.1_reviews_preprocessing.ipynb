# %% [markdown]
# # Data Pre-process for Movies Reviews

# %% [markdown]
# ## IMDb Movies Reviews

# %% [markdown]
# ### Import Packages

# %%
import os
import pandas as pd

# %% [markdown]
# **Note: Due to large datasets, we have run the codes in VS code instead of Google Colab for this preprocessing**

# %% [markdown]
# ### Step 1: Combine All Reviews into a Single CSV File
#
# - Since the raw dataset filenames represent the movie titles, add a new column, movie_title, to each CSV file during processing.
#
# - After processing all individual files, concatenate all DataFrames in the list into a single DataFrame.
#
# - Save this combined DataFrame as a new CSV file, containing all reviews with their respective movie titles.

# %%
# Specify the directory containing the CSV files
directory = 'C:\\xxx\\Raw_Datasets\\2_reviews_per_movie_raw'
combined_data = []  # List to hold all DataFrames

# Loop through each file in the directory
for filename in os.listdir(directory):
    if filename.endswith('.csv'):
        # Create the full file path
        file_path = os.path.join(directory, filename)
        
        # Read the CSV file into a DataFrame
        df = pd.read_csv(file_path)
        
        # Extract the movie title from the filename (without .csv extension)
        movie_title = os.path.splitext(filename)[0]  # This removes the .csv extension
        
        # Add a new column 'movie_title' with the extracted title
        df['movie_title'] = movie_title
        
        # Append the DataFrame to the list
        combined_data.append(df)
        
        new_directory = 'C:\\xxx\\Data_Preprocess\\Processed_Datasets'

        # Create a new file path for the updated CSV file
        new_file_path = os.path.join(new_directory, f"{movie_title}.csv")
        
        # Save the updated DataFrame to a new CSV file
        df.to_csv(new_file_path, index=False)

        print(f"Created new file {new_file_path} with movie_title: {movie_title}")

# Combine all DataFrames into a single DataFrame
final_combined_df = pd.concat(combined_data, ignore_index=True)

# Save the combined DataFrame to a new CSV file
final_combined_df.to_csv('imdb_movie_reviews_raw.csv', index=False)

print(f"All data combined and saved")
# Out:
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\10 Cloverfield Lane 2016.csv with movie_title: 10 Cloverfield Lane 2016
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\10 Things I Hate About You 1999.csv with movie_title: 10 Things I Hate About You 1999
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\12 Angry Men 1957.csv with movie_title: 12 Angry Men 1957
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\12 Monkeys 1995.csv with movie_title: 12 Monkeys 1995
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\12 Strong 2018.csv with movie_title: 12 Strong 2018
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\12 Years a Slave 2013.csv with movie_title: 12 Years a Slave 2013
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\127 Hours 2010.csv with movie_title: 127 Hours 2010
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\13 Hours 2016.csv with movie_title: 13 Hours 2016
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\1408 2007.csv with movie_title: 1408 2007
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\1917 2019.csv with movie_title: 1917 2019
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\1941 1979.csv with movie_title: 1941 1979
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\2001_ A Space Odyssey 1968.csv with movie_title: 2001_ A Space Odyssey 1968
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\2012 2009.csv with movie_title: 2012 2009
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\21 2008.csv with movie_title: 21 2008
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\21 Jump Street 2012.csv with movie_title: 21 Jump Street 2012
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\22 Jump Street 2014.csv with movie_title: 22 Jump Street 2014
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\28 Days Later... 2002.csv with movie_title: 28 Days Later... 2002
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\28 Weeks Later 2007.csv with movie_title: 28 Weeks Later 2007
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\3 Idiots 2009.csv with movie_title: 3 Idiots 2009
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\30 Days of Night 2007.csv with movie_title: 30 Days of Night 2007
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\300 2006.csv with movie_title: 300 2006
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\3_10 to Yuma 2007.csv with movie_title: 3_10 to Yuma 2007
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\42 2013.csv with movie_title: 42 2013
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\50 First Dates 2004.csv with movie_title: 50 First Dates 2004
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\500 Days of Summer 2009.csv with movie_title: 500 Days of Summer 2009
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\50_50 2011.csv with movie_title: 50_50 2011
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\54 1998.csv with movie_title: 54 1998
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\8 Mile 2002.csv with movie_title: 8 Mile 2002
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\A Beautiful Mind 2001.csv with movie_title: A Beautiful Mind 2001
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\A Bridge Too Far 1977.csv with movie_title: A Bridge Too Far 1977
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\A Bug's Life 1998.csv with movie_title: A Bug's Life 1998
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\A Clockwork Orange 1971.csv with movie_title: A Clockwork Orange 1971
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\A Hard Day's Night 1964.csv with movie_title: A Hard Day's Night 1964
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\A Night at the Roxbury 1998.csv with movie_title: A Night at the Roxbury 1998
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\A Nightmare on Elm Street 1984.csv with movie_title: A Nightmare on Elm Street 1984
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\A Quiet Place 2018.csv with movie_title: A Quiet Place 2018
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\A Star Is Born 2018.csv with movie_title: A Star Is Born 2018
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\A Walk to Remember 2002.csv with movie_title: A Walk to Remember 2002
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\About Time 2013.csv with movie_title: About Time 2013
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Abraham Lincoln_ Vampire Hunter 2012.csv with movie_title: Abraham Lincoln_ Vampire Hunter 2012
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Across the Universe 2007.csv with movie_title: Across the Universe 2007
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Airlift 2016.csv with movie_title: Airlift 2016
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Akira 1988.csv with movie_title: Akira 1988
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Aladdin 1992.csv with movie_title: Aladdin 1992
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Aladdin 2019.csv with movie_title: Aladdin 2019
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Alexander 2004.csv with movie_title: Alexander 2004
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Ali 2001.csv with movie_title: Ali 2001
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Alice in Wonderland 2010.csv with movie_title: Alice in Wonderland 2010
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Alien 1979.csv with movie_title: Alien 1979
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Alien 3 1992.csv with movie_title: Alien 3 1992
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Alien vs. Predator 2004.csv with movie_title: Alien vs. Predator 2004
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Aliens 1986.csv with movie_title: Aliens 1986
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Alien_ Covenant 2017.csv with movie_title: Alien_ Covenant 2017
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Alien_ Resurrection 1997.csv with movie_title: Alien_ Resurrection 1997
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\All Quiet on the Western Front 1930.csv with movie_title: All Quiet on the Western Front 1930
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\All the President's Men 1976.csv with movie_title: All the President's Men 1976
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Amadeus 1984.csv with movie_title: Amadeus 1984
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\American Beauty 1999.csv with movie_title: American Beauty 1999
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\American Gangster 2007.csv with movie_title: American Gangster 2007
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\American History X 1998.csv with movie_title: American History X 1998
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\American Hustle 2013.csv with movie_title: American Hustle 2013
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\American Made 2017.csv with movie_title: American Made 2017
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\American Pie 1999.csv with movie_title: American Pie 1999
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\American Psycho 2000.csv with movie_title: American Psycho 2000
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\American Sniper 2014.csv with movie_title: American Sniper 2014
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Ame╠ülie 2001.csv with movie_title: Ame╠ülie 2001
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Amistad 1997.csv with movie_title: Amistad 1997
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Anchorman_ The Legend of Ron Burgundy 2004.csv with movie_title: Anchorman_ The Legend of Ron Burgundy 2004
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Angels & Demons 2009.csv with movie_title: Angels & Demons 2009
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Annie Hall 1977.csv with movie_title: Annie Hall 1977
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Annihilation 2018.csv with movie_title: Annihilation 2018
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Ant-Man 2015.csv with movie_title: Ant-Man 2015
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Antz 1998.csv with movie_title: Antz 1998
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Any Given Sunday 1999.csv with movie_title: Any Given Sunday 1999
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Apocalypse Now 1979.csv with movie_title: Apocalypse Now 1979
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Apollo 13 1995.csv with movie_title: Apollo 13 1995
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Aquaman 2018.csv with movie_title: Aquaman 2018
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Argo 2012.csv with movie_title: Argo 2012
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Armageddon 1998.csv with movie_title: Armageddon 1998
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Army of Darkness 1992.csv with movie_title: Army of Darkness 1992
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Arrival 2016.csv with movie_title: Arrival 2016
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\As Good as It Gets 1997.csv with movie_title: As Good as It Gets 1997
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Atonement 2007.csv with movie_title: Atonement 2007
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Au Revoir les Enfants 1987.csv with movie_title: Au Revoir les Enfants 1987
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\August Rush 2007.csv with movie_title: August Rush 2007
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Avatar 2009.csv with movie_title: Avatar 2009
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Avengers_ Age of Ultron 2015.csv with movie_title: Avengers_ Age of Ultron 2015
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Avengers_ Endgame 2019.csv with movie_title: Avengers_ Endgame 2019
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Avengers_ Infinity War 2018.csv with movie_title: Avengers_ Infinity War 2018
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Baby Driver 2017.csv with movie_title: Baby Driver 2017
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Back to the Future 1985.csv with movie_title: Back to the Future 1985
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Back to the Future Part II 1989.csv with movie_title: Back to the Future Part II 1989
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Back to the Future Part III 1990.csv with movie_title: Back to the Future Part III 1990
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Bad Teacher 2011.csv with movie_title: Bad Teacher 2011
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Balls of Fury 2007.csv with movie_title: Balls of Fury 2007
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Barry Lyndon 1975.csv with movie_title: Barry Lyndon 1975
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\BASEketball 1998.csv with movie_title: BASEketball 1998
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Batman Begins 2005.csv with movie_title: Batman Begins 2005
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Batman Returns 1992.csv with movie_title: Batman Returns 1992
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Batman v Superman_ Dawn of Justice 2016.csv with movie_title: Batman v Superman_ Dawn of Justice 2016
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Battleship Potemkin 1925.csv with movie_title: Battleship Potemkin 1925
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Beasts of No Nation 2015.csv with movie_title: Beasts of No Nation 2015
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Beauty and the Beast 1991.csv with movie_title: Beauty and the Beast 1991
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Beauty and the Beast 2017.csv with movie_title: Beauty and the Beast 2017
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Beetlejuice 1988.csv with movie_title: Beetlejuice 1988
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Before Sunrise 1995.csv with movie_title: Before Sunrise 1995
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Before Sunset 2004.csv with movie_title: Before Sunset 2004
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Begin Again 2013.csv with movie_title: Begin Again 2013
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Behind The Candelabra 2013.csv with movie_title: Behind The Candelabra 2013
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Being John Malkovich 1999.csv with movie_title: Being John Malkovich 1999
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Ben-Hur 1959.csv with movie_title: Ben-Hur 1959
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Beowulf 2007.csv with movie_title: Beowulf 2007
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Bhaag Milkha Bhaag 2013.csv with movie_title: Bhaag Milkha Bhaag 2013
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Big Fish 2003.csv with movie_title: Big Fish 2003
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Big Hero 6 2014.csv with movie_title: Big Hero 6 2014
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Bill & Ted's Excellent Adventure 1989.csv with movie_title: Bill & Ted's Excellent Adventure 1989
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Billy Elliot 2000.csv with movie_title: Billy Elliot 2000
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Bird Box 2018.csv with movie_title: Bird Box 2018
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Birdman or (The Unexpected Virtue of Ignorance) 2014.csv with movie_title: Birdman or (The Unexpected Virtue of Ignorance) 2014
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Black Book 2006.csv with movie_title: Black Book 2006
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Black Hawk Down 2001.csv with movie_title: Black Hawk Down 2001
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Black Mass 2015.csv with movie_title: Black Mass 2015
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Black Panther 2018.csv with movie_title: Black Panther 2018
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Black Snake Moan 2006.csv with movie_title: Black Snake Moan 2006
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Black Swan 2010.csv with movie_title: Black Swan 2010
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\BlacKkKlansman 2018.csv with movie_title: BlacKkKlansman 2018
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Blade 1998.csv with movie_title: Blade 1998
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Blade II 2002.csv with movie_title: Blade II 2002
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Blade Runner 1982.csv with movie_title: Blade Runner 1982
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Blade Runner 2049 2017.csv with movie_title: Blade Runner 2049 2017
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Blades of Glory 2007.csv with movie_title: Blades of Glory 2007
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Blood Diamond 2006.csv with movie_title: Blood Diamond 2006
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Bloody Sunday 2002.csv with movie_title: Bloody Sunday 2002
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Blow 2001.csv with movie_title: Blow 2001
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Blue Crush 2002.csv with movie_title: Blue Crush 2002
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Bohemian Rhapsody 2018.csv with movie_title: Bohemian Rhapsody 2018
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Bolt 2008.csv with movie_title: Bolt 2008
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Borat_ Cultural Learnings of America for Make Benefit Glorious Nation of Kazakhstan 2006.csv with movie_title: Borat_ Cultural Learnings of America for Make Benefit Glorious Nation of Kazakhstan 2006
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Born on the Fourth of July 1989.csv with movie_title: Born on the Fourth of July 1989
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Bram Stoker's Dracula 1992.csv with movie_title: Bram Stoker's Dracula 1992
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Brave 2012.csv with movie_title: Brave 2012
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Braveheart 1995.csv with movie_title: Braveheart 1995
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Bridesmaids 2011.csv with movie_title: Bridesmaids 2011
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Bridge of Spies 2015.csv with movie_title: Bridge of Spies 2015
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Bridget Jones's Diary 2001.csv with movie_title: Bridget Jones's Diary 2001
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Bring It On 2000.csv with movie_title: Bring It On 2000
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Brokeback Mountain 2005.csv with movie_title: Brokeback Mountain 2005
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Bruce Almighty 2003.csv with movie_title: Bruce Almighty 2003
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Bull Durham 1988.csv with movie_title: Bull Durham 1988
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Burlesque 2010.csv with movie_title: Burlesque 2010
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Burn After Reading 2008.csv with movie_title: Burn After Reading 2008
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Butch Cassidy and the Sundance Kid 1969.csv with movie_title: Butch Cassidy and the Sundance Kid 1969
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Caddyshack 1980.csv with movie_title: Caddyshack 1980
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Call Me by Your Name 2017.csv with movie_title: Call Me by Your Name 2017
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Capote 2005.csv with movie_title: Capote 2005
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Captain America_ Civil War 2016.csv with movie_title: Captain America_ Civil War 2016
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Captain America_ The First Avenger 2011.csv with movie_title: Captain America_ The First Avenger 2011
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Captain America_ The Winter Soldier 2014.csv with movie_title: Captain America_ The Winter Soldier 2014
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Captain Corelli's Mandolin 2001.csv with movie_title: Captain Corelli's Mandolin 2001
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Captain Marvel 2019.csv with movie_title: Captain Marvel 2019
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Captain Phillips 2013.csv with movie_title: Captain Phillips 2013
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Carrie 1976.csv with movie_title: Carrie 1976
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Cars 2 2011.csv with movie_title: Cars 2 2011
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Cars 2006.csv with movie_title: Cars 2006
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Casablanca 1942.csv with movie_title: Casablanca 1942
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Casino 1995.csv with movie_title: Casino 1995
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Casino Royale 2006.csv with movie_title: Casino Royale 2006
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Cast Away 2000.csv with movie_title: Cast Away 2000
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Castle in the Sky 1986.csv with movie_title: Castle in the Sky 1986
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Casualties of War 1989.csv with movie_title: Casualties of War 1989
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Catch Me If You Can 2002.csv with movie_title: Catch Me If You Can 2002
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Catch-22 1970.csv with movie_title: Catch-22 1970
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Centurion 2010.csv with movie_title: Centurion 2010
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Chak de! India 2007.csv with movie_title: Chak de! India 2007
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Changeling 2008.csv with movie_title: Changeling 2008
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Chariots of Fire 1981.csv with movie_title: Chariots of Fire 1981
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Charlie and the Chocolate Factory 2005.csv with movie_title: Charlie and the Chocolate Factory 2005
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Chicken Run 2000.csv with movie_title: Chicken Run 2000
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Child 44 2015.csv with movie_title: Child 44 2015
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Children of Heaven 1997.csv with movie_title: Children of Heaven 1997
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Children of Men 2006.csv with movie_title: Children of Men 2006
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Chinatown 1974.csv with movie_title: Chinatown 1974
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Cinderella 1950.csv with movie_title: Cinderella 1950
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Cinderella Man 2005.csv with movie_title: Cinderella Man 2005
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Citizen Kane 1941.csv with movie_title: Citizen Kane 1941
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\City of God 2002.csv with movie_title: City of God 2002
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Clash of the Titans 2010.csv with movie_title: Clash of the Titans 2010
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Click 2006.csv with movie_title: Click 2006
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Climax 2018.csv with movie_title: Climax 2018
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Closer 2004.csv with movie_title: Closer 2004
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Cloud Atlas 2012.csv with movie_title: Cloud Atlas 2012
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Cloudy with a Chance of Meatballs 2009.csv with movie_title: Cloudy with a Chance of Meatballs 2009
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Cloverfield 2008.csv with movie_title: Cloverfield 2008
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Coach Carter 2005.csv with movie_title: Coach Carter 2005
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Coco 2017.csv with movie_title: Coco 2017
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Coffee and Cigarettes 2003.csv with movie_title: Coffee and Cigarettes 2003
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Cold Mountain 2003.csv with movie_title: Cold Mountain 2003
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Cold War 2018.csv with movie_title: Cold War 2018
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Collateral 2004.csv with movie_title: Collateral 2004
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Come and See 1985.csv with movie_title: Come and See 1985
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Con Air 1997.csv with movie_title: Con Air 1997
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Concussion 2015.csv with movie_title: Concussion 2015
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Conquest 1453 2012.csv with movie_title: Conquest 1453 2012
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Constantine 2005.csv with movie_title: Constantine 2005
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Contact 1997.csv with movie_title: Contact 1997
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Control 2007.csv with movie_title: Control 2007
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Coraline 2009.csv with movie_title: Coraline 2009
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Coriolanus 2011.csv with movie_title: Coriolanus 2011
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Corpse Bride 2005.csv with movie_title: Corpse Bride 2005
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Coyote Ugly 2000.csv with movie_title: Coyote Ugly 2000
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Crash 2004.csv with movie_title: Crash 2004
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Crazy Heart 2009.csv with movie_title: Crazy Heart 2009
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Crazy, Stupid, Love 2011.csv with movie_title: Crazy, Stupid, Love 2011
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Creed 2015.csv with movie_title: Creed 2015
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Creed II 2018.csv with movie_title: Creed II 2018
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Cross of Iron 1977.csv with movie_title: Cross of Iron 1977
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Crouching Tiger, Hidden Dragon 2000.csv with movie_title: Crouching Tiger, Hidden Dragon 2000
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Cube 1997.csv with movie_title: Cube 1997
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Da 5 Bloods 2020.csv with movie_title: Da 5 Bloods 2020
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Dallas Buyers Club 2013.csv with movie_title: Dallas Buyers Club 2013
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Dangal 2016.csv with movie_title: Dangal 2016
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Dark City 1998.csv with movie_title: Dark City 1998
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Dark Shadows 2012.csv with movie_title: Dark Shadows 2012
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Darkest Hour 2017.csv with movie_title: Darkest Hour 2017
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Dawn of the Dead 2004.csv with movie_title: Dawn of the Dead 2004
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Days of Thunder 1990.csv with movie_title: Days of Thunder 1990
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Dead Poets Society 1989.csv with movie_title: Dead Poets Society 1989
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Deadpool 2 2018.csv with movie_title: Deadpool 2 2018
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Deadpool 2016.csv with movie_title: Deadpool 2016
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Dear John 2010.csv with movie_title: Dear John 2010
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Deepwater Horizon 2016.csv with movie_title: Deepwater Horizon 2016
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Defiance 2008.csv with movie_title: Defiance 2008
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Deja Vu 2006.csv with movie_title: Deja Vu 2006
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Departures 2008.csv with movie_title: Departures 2008
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Despicable Me 2 2013.csv with movie_title: Despicable Me 2 2013
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Despicable Me 2010.csv with movie_title: Despicable Me 2010
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Detroit 2017.csv with movie_title: Detroit 2017
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Detroit Rock City 1999.csv with movie_title: Detroit Rock City 1999
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Die Hard 1988.csv with movie_title: Die Hard 1988
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Die Hard 2 1990.csv with movie_title: Die Hard 2 1990
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Die Hard with a Vengeance 1995.csv with movie_title: Die Hard with a Vengeance 1995
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Dirty Dancing 1987.csv with movie_title: Dirty Dancing 1987
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\District 9 2009.csv with movie_title: District 9 2009
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Disturbia 2007.csv with movie_title: Disturbia 2007
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Divergent 2014.csv with movie_title: Divergent 2014
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Django Unchained 2012.csv with movie_title: Django Unchained 2012
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Doctor Strange 2016.csv with movie_title: Doctor Strange 2016
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Doctor Zhivago 1965.csv with movie_title: Doctor Zhivago 1965
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Dodgeball 2004.csv with movie_title: Dodgeball 2004
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Dog Day Afternoon 1975.csv with movie_title: Dog Day Afternoon 1975
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Don Jon 2013.csv with movie_title: Don Jon 2013
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Don't Breathe 2016.csv with movie_title: Don't Breathe 2016
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Donnie Brasco 1997.csv with movie_title: Donnie Brasco 1997
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Donnie Darko 2001.csv with movie_title: Donnie Darko 2001
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Downfall 2004.csv with movie_title: Downfall 2004
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Dr. Strangelove or_ How I Learned to Stop Worrying and Love the Bomb 1964.csv with movie_title: Dr. Strangelove or_ How I Learned to Stop Worrying and Love the Bomb 1964
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Draft Day 2014.csv with movie_title: Draft Day 2014
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Drag Me to Hell 2009.csv with movie_title: Drag Me to Hell 2009
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Dreamgirls 2006.csv with movie_title: Dreamgirls 2006
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Drive 2011.csv with movie_title: Drive 2011
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Driven 2001.csv with movie_title: Driven 2001
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Duck Soup 1933.csv with movie_title: Duck Soup 1933
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Duck You Sucker 1971.csv with movie_title: Duck You Sucker 1971
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Dumb and Dumber 1994.csv with movie_title: Dumb and Dumber 1994
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Dunkirk 2017.csv with movie_title: Dunkirk 2017
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\E.T. the Extra-Terrestrial 1982.csv with movie_title: E.T. the Extra-Terrestrial 1982
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Easy A 2010.csv with movie_title: Easy A 2010
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Ed Wood 1994.csv with movie_title: Ed Wood 1994
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Edge of Tomorrow 2014.csv with movie_title: Edge of Tomorrow 2014
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Edward Scissorhands 1990.csv with movie_title: Edward Scissorhands 1990
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Elf 2003.csv with movie_title: Elf 2003
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Elizabeth 1998.csv with movie_title: Elizabeth 1998
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Elizabeth_ The Golden Age 2007.csv with movie_title: Elizabeth_ The Golden Age 2007
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Elysium 2013.csv with movie_title: Elysium 2013
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Empire of the Sun 1987.csv with movie_title: Empire of the Sun 1987
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Empire Records 1995.csv with movie_title: Empire Records 1995
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Enchanted 2007.csv with movie_title: Enchanted 2007
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Ender's Game 2013.csv with movie_title: Ender's Game 2013
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Enemy at the Gates 2001.csv with movie_title: Enemy at the Gates 2001
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Erin Brockovich 2000.csv with movie_title: Erin Brockovich 2000
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Eternal Sunshine of the Spotless Mind 2004.csv with movie_title: Eternal Sunshine of the Spotless Mind 2004
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Eurovision Song Contest_ The Story of Fire Saga 2020.csv with movie_title: Eurovision Song Contest_ The Story of Fire Saga 2020
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Event Horizon 1997.csv with movie_title: Event Horizon 1997
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Everest 2015.csv with movie_title: Everest 2015
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Evil Dead 2013.csv with movie_title: Evil Dead 2013
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Evil Dead II 1987.csv with movie_title: Evil Dead II 1987
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Ex Machina 2014.csv with movie_title: Ex Machina 2014
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Eyes Wide Shut 1999.csv with movie_title: Eyes Wide Shut 1999
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Face_Off 1997.csv with movie_title: Face_Off 1997
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Fantastic 4_ Rise of the Silver Surfer 2007.csv with movie_title: Fantastic 4_ Rise of the Silver Surfer 2007
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Fantastic Beasts and Where to Find Them 2016.csv with movie_title: Fantastic Beasts and Where to Find Them 2016
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Fantastic Four 2005.csv with movie_title: Fantastic Four 2005
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Fantastic Mr. Fox 2009.csv with movie_title: Fantastic Mr. Fox 2009
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Fargo 1996.csv with movie_title: Fargo 1996
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Fast & Furious 6 2013.csv with movie_title: Fast & Furious 6 2013
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Fast Five 2011.csv with movie_title: Fast Five 2011
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Fifty Shades of Grey 2015.csv with movie_title: Fifty Shades of Grey 2015
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Fight Club 1999.csv with movie_title: Fight Club 1999
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Final Destination 2 2003.csv with movie_title: Final Destination 2 2003
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Final Destination 2000.csv with movie_title: Final Destination 2000
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Finding Dory 2016.csv with movie_title: Finding Dory 2016
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Finding Nemo 2003.csv with movie_title: Finding Nemo 2003
# ...
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Thirteen Days 2000.csv with movie_title: Thirteen Days 2000
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\This Is Spinal Tap 1984.csv with movie_title: This Is Spinal Tap 1984
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\This Is the End 2013.csv with movie_title: This Is the End 2013
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Thor 2011.csv with movie_title: Thor 2011
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Thor_ Ragnarok 2017.csv with movie_title: Thor_ Ragnarok 2017
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Thor_ The Dark World 2013.csv with movie_title: Thor_ The Dark World 2013
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Three Billboards Outside Ebbing, Missouri 2017.csv with movie_title: Three Billboards Outside Ebbing, Missouri 2017
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Three Colors_ Blue 1993.csv with movie_title: Three Colors_ Blue 1993
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Tigerland 2000.csv with movie_title: Tigerland 2000
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Tinker Tailor Soldier Spy 2011.csv with movie_title: Tinker Tailor Soldier Spy 2011
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Titanic 1997.csv with movie_title: Titanic 1997
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\To Be or Not to Be 1942.csv with movie_title: To Be or Not to Be 1942
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\To Kill a Mockingbird 1962.csv with movie_title: To Kill a Mockingbird 1962
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\To Rome With Love 2012.csv with movie_title: To Rome With Love 2012
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Tombstone 1993.csv with movie_title: Tombstone 1993
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Top Secret! 1984.csv with movie_title: Top Secret! 1984
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Total Recall 1990.csv with movie_title: Total Recall 1990
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Toy Story 1995.csv with movie_title: Toy Story 1995
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Toy Story 2 1999.csv with movie_title: Toy Story 2 1999
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Toy Story 3 2010.csv with movie_title: Toy Story 3 2010
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Toy Story 4 2019.csv with movie_title: Toy Story 4 2019
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Train to Busan 2016.csv with movie_title: Train to Busan 2016
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Training Day 2001.csv with movie_title: Training Day 2001
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Trainspotting 1996.csv with movie_title: Trainspotting 1996
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Transformers 2007.csv with movie_title: Transformers 2007
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Transformers_ Dark of the Moon 2011.csv with movie_title: Transformers_ Dark of the Moon 2011
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Transformers_ Revenge of the Fallen 2009.csv with movie_title: Transformers_ Revenge of the Fallen 2009
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Tropic Thunder 2008.csv with movie_title: Tropic Thunder 2008
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Trouble with the Curve 2012.csv with movie_title: Trouble with the Curve 2012
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Troy 2004.csv with movie_title: Troy 2004
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\True Romance 1993.csv with movie_title: True Romance 1993
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Tucker and Dale vs Evil 2010.csv with movie_title: Tucker and Dale vs Evil 2010
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Twilight 2008.csv with movie_title: Twilight 2008
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Two for the Money 2005.csv with movie_title: Two for the Money 2005
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\U-571 2000.csv with movie_title: U-571 2000
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Unbreakable 2000.csv with movie_title: Unbreakable 2000
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Unbroken 2014.csv with movie_title: Unbroken 2014
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Underground 1995.csv with movie_title: Underground 1995
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Underworld 2003.csv with movie_title: Underworld 2003
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Underworld Awakening 2012.csv with movie_title: Underworld Awakening 2012
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\United 93 2006.csv with movie_title: United 93 2006
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Unknown 2011.csv with movie_title: Unknown 2011
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Up 2009.csv with movie_title: Up 2009
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Up in the Air 2009.csv with movie_title: Up in the Air 2009
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Uri_ The Surgical Strike 2019.csv with movie_title: Uri_ The Surgical Strike 2019
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Us 2019.csv with movie_title: Us 2019
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\V for Vendetta 2005.csv with movie_title: V for Vendetta 2005
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Valkyrie 2008.csv with movie_title: Valkyrie 2008
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Van Helsing 2004.csv with movie_title: Van Helsing 2004
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Vanilla Sky 2001.csv with movie_title: Vanilla Sky 2001
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Velvet Goldmine 1998.csv with movie_title: Velvet Goldmine 1998
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Vertigo 1958.csv with movie_title: Vertigo 1958
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Vicky Cristina Barcelona 2008.csv with movie_title: Vicky Cristina Barcelona 2008
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Victory 1981.csv with movie_title: Victory 1981
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Walk Hard_ The Dewey Cox Story 2007.csv with movie_title: Walk Hard_ The Dewey Cox Story 2007
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Walk the Line 2005.csv with movie_title: Walk the Line 2005
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\WALL┬╖E 2008.csv with movie_title: WALL┬╖E 2008
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Wanted 2008.csv with movie_title: Wanted 2008
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\War Dogs 2016.csv with movie_title: War Dogs 2016
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\War Machine 2017.csv with movie_title: War Machine 2017
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\War of the Worlds 2005.csv with movie_title: War of the Worlds 2005
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Warcraft 2016.csv with movie_title: Warcraft 2016
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Warm Bodies 2013.csv with movie_title: Warm Bodies 2013
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Warrior 2011.csv with movie_title: Warrior 2011
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Watchmen 2009.csv with movie_title: Watchmen 2009
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Wayne's World 1992.csv with movie_title: Wayne's World 1992
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\We Are Marshall 2006.csv with movie_title: We Are Marshall 2006
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\We Were Soldiers 2002.csv with movie_title: We Were Soldiers 2002
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\We're the Millers 2013.csv with movie_title: We're the Millers 2013
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Wedding Crashers 2005.csv with movie_title: Wedding Crashers 2005
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\What We Do in the Shadows 2014.csv with movie_title: What We Do in the Shadows 2014
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\When Harry Met Sally... 1989.csv with movie_title: When Harry Met Sally... 1989
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Where Eagles Dare 1968.csv with movie_title: Where Eagles Dare 1968
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Whip It 2009.csv with movie_title: Whip It 2009
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Whiplash 2014.csv with movie_title: Whiplash 2014
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Who Framed Roger Rabbit 1988.csv with movie_title: Who Framed Roger Rabbit 1988
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Wimbledon 2004.csv with movie_title: Wimbledon 2004
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Win Win 2011.csv with movie_title: Win Win 2011
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Wind River 2017.csv with movie_title: Wind River 2017
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Windtalkers 2002.csv with movie_title: Windtalkers 2002
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Woman in Gold 2015.csv with movie_title: Woman in Gold 2015
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Wonder Woman 2017.csv with movie_title: Wonder Woman 2017
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\World Trade Center 2006.csv with movie_title: World Trade Center 2006
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\World War Z 2013.csv with movie_title: World War Z 2013
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Wreck-It Ralph 2012.csv with movie_title: Wreck-It Ralph 2012
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\X-Men 2000.csv with movie_title: X-Men 2000
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\X-Men Origins_ Wolverine 2009.csv with movie_title: X-Men Origins_ Wolverine 2009
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\X-Men_ Apocalypse 2016.csv with movie_title: X-Men_ Apocalypse 2016
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\X-Men_ Days of Future Past 2014.csv with movie_title: X-Men_ Days of Future Past 2014
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\X-Men_ First Class 2011.csv with movie_title: X-Men_ First Class 2011
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\X-Men_ The Last Stand 2006.csv with movie_title: X-Men_ The Last Stand 2006
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\X2_ X-Men United 2003.csv with movie_title: X2_ X-Men United 2003
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Yes Man 2008.csv with movie_title: Yes Man 2008
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Yesterday 2019.csv with movie_title: Yesterday 2019
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Your Name. 2016.csv with movie_title: Your Name. 2016
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Youth 2015.csv with movie_title: Youth 2015
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Zero Dark Thirty 2012.csv with movie_title: Zero Dark Thirty 2012
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Zodiac 2007.csv with movie_title: Zodiac 2007
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Zombieland 2009.csv with movie_title: Zombieland 2009
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Zootopia 2016.csv with movie_title: Zootopia 2016
# Created new file C:\Users\laihu\Desktop\BT4222\BT4222 Project\Data_Processing\Processed_Datasets\Zulu 1964.csv with movie_title: Zulu 1964
# All data combined and saved

# %% [markdown]
# ### Step 2: Extract Data Fields from JSON
#
# - Additional IMDb movies reviews raw data can be found in ebD_json

# %%
import json
import os

# Use a raw string or double backslashes for the path
directory = r'C:\\Users\\xxx\\Datasets\\Raw Datasets\\ebD_json'  # Update this with your actual path

# Initialize a list to hold the extracted data
all_data = []

# Iterate through each file in the specified directory
try:
    for filename in os.listdir(directory):
        if filename.endswith('.json'):  # Check if the file is a JSON file
            file_path = os.path.join(directory, filename)  # Construct the full file path
            
            # Load JSON data from the file
            with open(file_path, 'r', encoding='utf-8') as file:
                data = json.load(file)

                # Print the data structure to understand its format
                print(f"Data from {filename}:")

                for item in data:
                    all_data.append({
                        'reviewer': item.get('reviewer', ''),
                        'movie': item.get('movie', ''),
                        'rating': item.get('rating', ''),
                        'review_date': item.get('review_date', ''),
                        'review_detail': item.get('review_detail', '')
                    })
                print(f"Complete append for data from {filename}")

    # Create a DataFrame from the collected data
    df = pd.DataFrame(all_data)

    # Optionally, save the DataFrame to a CSV file
    df.to_csv('IMDB_review_edb_raw.csv', index=False)
    
    print("File saved!")

except FileNotFoundError as e:
    print(f"Error: {e}")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Data from part-01.json:
# Complete append for data from part-01.json
# Data from part-02.json:
# Complete append for data from part-02.json
# Data from part-03.json:
# Complete append for data from part-03.json
# Data from part-04.json:
# Complete append for data from part-04.json
# Data from part-05.json:
# Complete append for data from part-05.json
# Data from part-06.json:
# Complete append for data from part-06.json

# %% [markdown]
# ### Step 3: Merge Datasets to Gather Additional Reviews
# Given that the edB dataset includes a mix of movies, dramas, and shows, we will concatenade records with the IMDb dataset to supplement with additional reviews specifically for the movies found in the IMDb dataset.

# %%
# Read the CSV file
df = pd.read_csv('imdb_movie_reviews_raw.csv')

# Display the first few rows of the dataframe
print(df.head())
# Out:
#         username rating  helpful  total             date  \
# 0  Imme-van-Gorp      7      102    123  30 January 2019
# 1  sonofocelot-1      5      385    500      10 May 2016
# 2        mhodaee      5      110    143    4 August 2017
# 3      fil-nik09      5       73    100   5 October 2016
# 4      DVR_Brale      7       42     56     27 July 2016
#
#                                                title  \
# 0   Unfortunately the ending ruined an otherwise ...
# 1                        ...oh dear Abrams. Again.\n
# 2   Fantastic, gripping, thoroughly enjoyable, un...
# 3                                          Hmmm...\n
# 4   Slow building & plot alternating claustrophob...
#
#                                               review               movie_title
# 0  This movie is full of suspense. It makes you g...  10 Cloverfield Lane 2016
# 1  I'll leave this review fairly concise. <br/><b...  10 Cloverfield Lane 2016
# 2  I give the 5/10 out of the credit I owe to the...  10 Cloverfield Lane 2016
# 3  First of all, I must say that I was expecting ...  10 Cloverfield Lane 2016
# 4  I've always loved movies with strong atmospher...  10 Cloverfield Lane 2016

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 932317 entries, 0 to 932316
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   username     932317 non-null  object
#  1   rating       932317 non-null  object
#  2   helpful      932317 non-null  int64
#  3   total        932317 non-null  int64
#  4   date         932317 non-null  object
#  5   title        932317 non-null  object
#  6   review       932317 non-null  object
#  7   movie_title  932317 non-null  object
# dtypes: int64(2), object(6)
# memory usage: 56.9+ MB

# %%
# Check Nulls
df.isna().sum()
# Out:
# username       0
# rating         0
# helpful        0
# total          0
# date           0
# title          0
# review         0
# movie_title    0
# dtype: int64

# %%
# Renaming the columns
df = df.rename(columns={'username': 'reviewer_name'})
df = df.rename(columns={'rating': 'reviewer_rating'})
df = df.rename(columns={'review': 'review_text'})

# Dropping columns
df = df.drop(columns=['helpful'])
df = df.drop(columns=['title'])
df = df.drop(columns=['total'])
df = df.drop(columns=['date'])

# %%
# Function to modify the movie title
def format_movie_title(title):
    # Split the title and year
    parts = title.rsplit(' ', 1)
    if len(parts) == 2 and parts[1].isdigit():
        return f"{parts[0]} ({parts[1]})"
    return title  # Return the original title if it doesn't match the pattern

# Apply the function to the 'movie_title' column
df['movie_title'] = df['movie_title'].apply(format_movie_title)

# Print unique movie titles
unique_titles = df['movie_title'].unique()
print(unique_titles)
# Out:
# ['10 Cloverfield Lane (2016)' '10 Things I Hate About You (1999)'
#  '12 Angry Men (1957)' ... 'Zombieland (2009)' 'Zootopia (2016)'
#  'Zulu (1964)']

# %%
# Read the CSV file
df2 = pd.read_csv('IMDB_review_edb_raw.csv')

# Display the first few rows of the dataframe
print(df2.head())
# Out:
#           reviewer                          movie  rating review_date  \
# 0    raeldor-96879            After Life (2019– )     9.0  3 May 2020
# 1          dosleeb  The Valhalla Murders (2019– )     6.0  3 May 2020
# 2  brightconscious           Special OPS (2020– )     7.0  3 May 2020
# 3       gasconyway              #BlackAF (2020– )     8.0  3 May 2020
# 4     mmason-15867             The Droving (2020)     2.0  3 May 2020
#
#                                        review_detail
# 0  I enjoyed the first season, but I must say I t...
# 1  I know Iceland is a small country and police d...
# 2  Except K K , no other actor looks comfortable ...
# 3  I'm guessing that as a 62 year old white woman...
# 4  Here's the truth. There's not much to this mov...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2059990 entries, 0 to 2059989
# Data columns (total 5 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   reviewer       object
#  1   movie          object
#  2   rating         float64
#  3   review_date    object
#  4   review_detail  object
# dtypes: float64(1), object(4)
# memory usage: 78.6+ MB

# %%
# Check Nulls
df2.isna().sum()
# Out:
# reviewer              0
# movie                 0
# rating           120411
# review_date           0
# review_detail         0
# dtype: int64

# %%
# Remove only the parentheses from the 'movie' column
df2['movie'] = df2['movie'].str.replace(r'[\(\)]', '', regex=True)

# Remove NA
df2 = df2.dropna()

# Perform an inner join to get only matching rows
df3 = df2[df2['movie'].isin(df['movie_title'])]

# Renaming the columns
df3 = df3.rename(columns={'reviewer': 'reviewer_name'})
df3 = df3.rename(columns={'rating': 'reviewer_rating'})
df3 = df3.rename(columns={'movie': 'movie_title'})
df3 = df3.rename(columns={'review_detail': 'review_text'})

# Concatenate df1 and df3 to create a new DataFrame
df_combined = pd.concat([df, df3[['reviewer_name', 'reviewer_rating', 'movie_title', 'review_text']]], ignore_index=True)

print(df_combined)
# Out:
#         reviewer_name reviewer_rating  \
# 0       Imme-van-Gorp               7
# 1       sonofocelot-1               5
# 2             mhodaee               5
# 3           fil-nik09               5
# 4           DVR_Brale               7
# ...               ...             ...
# 932312          rupie               8
# 932313       JohnSeal               8
# 932314          rmaki              10
# 932315          Grand               9
# 932316       mike-411              10
#
#                                               review_text  \
# 0       This movie is full of suspense. It makes you g...
# 1       I'll leave this review fairly concise. <br/><b...
# 2       I give the 5/10 out of the credit I owe to the...
# 3       First of all, I must say that I was expecting ...
# 4       I've always loved movies with strong atmospher...
# ...                                                   ...
# 932312  I found it most interesting to read the commen...
# 932313  Zulu is a film I can watch over and over again...
# 932314  This is a fantastic film of a true, historical...
# 932315  (I was getting chills just casting my vote for...
# 932316  I was immediately drawn into this movie when I...
#
#                        movie_title
# 0       10 Cloverfield Lane (2016)
# 1       10 Cloverfield Lane (2016)
# 2       10 Cloverfield Lane (2016)
# 3       10 Cloverfield Lane (2016)
# 4       10 Cloverfield Lane (2016)
# ...                            ...
# 932312                 Zulu (1964)
# 932313                 Zulu (1964)
# 932314                 Zulu (1964)
# 932315                 Zulu (1964)
# 932316                 Zulu (1964)
#
# [932317 rows x 4 columns]

# %% [markdown]
# ### Step 4: Data Cleaning
#
# - Change data types
#
# - Remove rows where `reviewer_rating` is null to ensure only valid ratings remain.

# %%
# Replace 'Null' with a valid integer or NaN
df_combined['reviewer_rating'] = df_combined['reviewer_rating'].replace('Null', pd.NA)
df_combined['reviewer_rating'] = pd.to_numeric(df_combined['reviewer_rating'], errors='coerce')
df_combined['review_text'] = df_combined['review_text'].replace('', pd.NA)
df_combined = df_combined.dropna()

# Changing the data type 
df_combined['reviewer_name'] = df_combined['reviewer_name'].astype(str)
df_combined['reviewer_rating'] = df_combined['reviewer_rating'].astype(float)
df_combined['review_text'] = df_combined['review_text'].astype(str)

# %%
# Edit movie title
# Extract the year (first four consecutive digits inside parentheses) and create a new column
df_combined['movie_year_of_release'] = df_combined['movie_title'].str.extract(r'\((\d{4})\)')
df_combined['movie_year_of_release'] = df_combined['movie_year_of_release'].astype('Int64')
df_combined['movie_title'] = df_combined['movie_title'].str.replace('_', ':')  # Replace '_' with ':'

# %%
# Remove duplicates
df_combined = df_combined.drop_duplicates()

# %%
df_combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 835448 entries, 0 to 932316
# Data columns (total 5 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   reviewer_name          835448 non-null  object
#  1   reviewer_rating        835448 non-null  float64
#  2   review_text            835448 non-null  object
#  3   movie_title            835448 non-null  object
#  4   movie_year_of_release  835448 non-null  Int64
# dtypes: Int64(1), float64(1), object(3)
# memory usage: 39.0+ MB

# %%
df_combined.head()
# Out:
#    reviewer_name  reviewer_rating  \
# 0  Imme-van-Gorp              7.0
# 1  sonofocelot-1              5.0
# 2        mhodaee              5.0
# 3      fil-nik09              5.0
# 4      DVR_Brale              7.0
#
#                                          review_text  \
# 0  This movie is full of suspense. It makes you g...
# 1  I'll leave this review fairly concise. <br/><b...
# 2  I give the 5/10 out of the credit I owe to the...
# 3  First of all, I must say that I was expecting ...
# 4  I've always loved movies with strong atmospher...
#
#                   movie_title  movie_year_of_release
# 0  10 Cloverfield Lane (2016)                   2016
# 1  10 Cloverfield Lane (2016)                   2016
# 2  10 Cloverfield Lane (2016)                   2016
# 3  10 Cloverfield Lane (2016)                   2016
# 4  10 Cloverfield Lane (2016)                   2016

# %% [markdown]
# ### Step 5: Check Statistics

# %%
# Descriptive statistics for the date column
movie_year_stats = {
    'count': df_combined['movie_year_of_release'].count(),
    'min': df_combined['movie_year_of_release'].min(),
    'max': df_combined['movie_year_of_release'].max(),
    'mean': df_combined['movie_year_of_release'].mean(),
    'mode': df_combined['movie_year_of_release'].mode()[0],
    'median': df_combined['movie_year_of_release'].median(),
    'sd': df_combined['movie_year_of_release'].std(),
}
print(movie_year_stats)

# Count the number of null values in 'column1'
null_count = df_combined['movie_year_of_release'].isnull().sum()
print(f"Number of null values in 'movie_year_of_release': {null_count}")
# Out:
# {'count': 835448, 'min': 1915, 'max': 2020, 'mean': 2005.5269508096255, 'mode': 2019, 'median': 2008.0, 'sd': 13.08674461545379}
# Number of null values in 'movie_year_of_release': 0

# %%
# Descriptive statistics for the date column
reviewer_rating_stats = {
    'count': df_combined['reviewer_rating'].count(),
    'min': df_combined['reviewer_rating'].min(),
    'max': df_combined['reviewer_rating'].max(),
    'mean': df_combined['reviewer_rating'].mean(),
    'mode': df_combined['reviewer_rating'].mode()[0],
    'median': df_combined['reviewer_rating'].median(),
    'sd': df_combined['reviewer_rating'].std(),
}
print(reviewer_rating_stats)

# Count the number of null values in 'column1'
null_count = df_combined['reviewer_rating'].isnull().sum()
print(f"Number of null values in 'reviewer_rating': {null_count}")
# Out:
# {'count': 835448, 'min': 1.0, 'max': 10.0, 'mean': 7.177997912497247, 'mode': 10.0, 'median': 8.0, 'sd': 2.8796077783944307}
# Number of null values in 'reviewer_rating': 0

# %%
# Count the number of null values in 'column1'
null_count = df_combined['review_text'].isnull().sum()
print(f"Number of null values in 'review_text': {null_count}")
# Out:
# Number of null values in 'review_text': 0

# %%
# Create a new DataFrame with review count and average rating for each reviewer
reviewer_stats = df_combined.groupby('reviewer_name').agg(
    review_count=('reviewer_rating', 'size'),
    average_rating=('reviewer_rating', 'mean')
).reset_index()

# Display the new DataFrame
print(reviewer_stats)
# Out:
#        reviewer_name  review_count  average_rating
# 0                !@N             2       10.000000
# 1         "Garfield"             1       10.000000
# 2            "Joker"             7        8.714286
# 3           "Manos!"             1        9.000000
# 4              "boz"             1        6.000000
# ...              ...           ...             ...
# 390845      ÇåtWømåñ             1       10.000000
# 390846           Óli             1       10.000000
# 390847     Øystein-3             4        5.250000
# 390848         ángel             2        8.000000
# 390849      •GRËNDEL             1       10.000000
#
# [390850 rows x 3 columns]

# %% [markdown]
# ## Rotten Tomatoes Movies Reviews

# %% [markdown]
# ### Step 1: Match id to get Movie Title for the reviews

# %%
# Read the CSV file into a DataFrame
df_rt = pd.read_csv('rotten_tomatoes_movie_reviews.csv')

df_rt.head()
# Out:
#                                   id  reviewId creationDate       criticName  \
# 0                            beavers   1145982   2003-05-23  Ivan M. Lincoln
# 1                         blood_mask   1636744   2007-06-02    The Foywonder
# 2  city_hunter_shinjuku_private_eyes   2590987   2019-05-28     Reuben Baron
# 3  city_hunter_shinjuku_private_eyes   2558908   2019-02-14      Matt Schley
# 4                 dangerous_men_2015   2504681   2018-08-29        Pat Padua
#
#    isTopCritic originalScore reviewState                 publicatioName  \
# 0        False         3.5/4       fresh  Deseret News (Salt Lake City)
# 1        False           1/5      rotten                  Dread Central
# 2        False           NaN       fresh                            CBR
# 3        False         2.5/5      rotten                    Japan Times
# 4        False           NaN       fresh                          DCist
#
#                                           reviewText scoreSentiment  \
# 0  Timed to be just long enough for most youngste...       POSITIVE
# 1  It doesn't matter if a movie costs 300 million...       NEGATIVE
# 2  The choreography is so precise and lifelike at...       POSITIVE
# 3  The film's out-of-touch attempts at humor may ...       NEGATIVE
# 4  Its clumsy determination is endearing and some...       POSITIVE
#
#                                            reviewUrl
# 0  http://www.deseretnews.com/article/700003233/B...
# 1  http://www.dreadcentral.com/index.php?name=Rev...
# 2  https://www.cbr.com/city-hunter-shinjuku-priva...
# 3  https://www.japantimes.co.jp/culture/2019/02/0...
# 4  http://dcist.com/2015/11/out_of_frame_dangerou...

# %%
df_rt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1444963 entries, 0 to 1444962
# Data columns (total 11 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
#  0   id              1444963 non-null  object
#  1   reviewId        1444963 non-null  int64
#  2   creationDate    1444963 non-null  object
#  3   criticName      1444963 non-null  object
#  4   isTopCritic     1444963 non-null  bool
#  5   originalScore   1009745 non-null  object
#  6   reviewState     1444963 non-null  object
#  7   publicatioName  1444963 non-null  object
#  8   reviewText      1375738 non-null  object
#  9   scoreSentiment  1444963 non-null  object
#  10  reviewUrl       1234038 non-null  object
# dtypes: bool(1), int64(1), object(9)
# memory usage: 111.6+ MB

# %%
# Check Nulls
df_rt.isna().sum()
# Out:
# id                     0
# reviewId               0
# creationDate           0
# criticName             0
# isTopCritic            0
# originalScore     435218
# reviewState            0
# publicatioName         0
# reviewText         69225
# scoreSentiment         0
# reviewUrl         210925
# dtype: int64

# %%
# Read the CSV file into a DataFrame
df_rt_movie = pd.read_csv('rotten_tomatoes_movies.csv')

df_rt_movie.head()
# Out:
#                      id                title  audienceScore  tomatoMeter  \
# 0    space-zombie-bingo  Space Zombie Bingo!           50.0          NaN
# 1       the_green_grass      The Green Grass            NaN          NaN
# 2             love_lies           Love, Lies           43.0          NaN
# 3  the_sore_losers_1997          Sore Losers           60.0          NaN
# 4  dinosaur_island_2002      Dinosaur Island           70.0          NaN
#
#   rating ratingContents releaseDateTheaters releaseDateStreaming  \
# 0    NaN            NaN                 NaN           2018-08-25
# 1    NaN            NaN                 NaN           2020-02-11
# 2    NaN            NaN                 NaN                  NaN
# 3    NaN            NaN                 NaN           2020-10-23
# 4    NaN            NaN                 NaN           2017-03-27
#
#    runtimeMinutes                          genre originalLanguage  \
# 0            75.0         Comedy, Horror, Sci-fi          English
# 1           114.0                          Drama          English
# 2           120.0                          Drama           Korean
# 3            90.0     Action, Mystery & thriller          English
# 4            80.0  Fantasy, Adventure, Animation          English
#
#                         director                                  writer  \
# 0                  George Ormrod              George Ormrod,John Sabotta
# 1                Tiffany Edwards                         Tiffany Edwards
# 2  Park Heung-Sik,Heung-Sik Park  Ha Young-Joon,Jeon Yun-su,Song Hye-jin
# 3          John Michael McCarthy                   John Michael McCarthy
# 4                  Will Meugniot                                John Loy
#
#   boxOffice distributor soundMix
# 0       NaN         NaN      NaN
# 1       NaN         NaN      NaN
# 2       NaN         NaN      NaN
# 3       NaN         NaN      NaN
# 4       NaN         NaN      NaN

# %%
df_rt_movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 143258 entries, 0 to 143257
# Data columns (total 16 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   id                    143258 non-null  object
#  1   title                 142891 non-null  object
#  2   audienceScore         73248 non-null   float64
#  3   tomatoMeter           33877 non-null   float64
#  4   rating                13991 non-null   object
#  5   ratingContents        13991 non-null   object
#  6   releaseDateTheaters   30773 non-null   object
#  7   releaseDateStreaming  79420 non-null   object
#  8   runtimeMinutes        129431 non-null  float64
#  9   genre                 132175 non-null  object
#  10  originalLanguage      129400 non-null  object
#  11  director              139041 non-null  object
#  12  writer                90116 non-null   object
#  13  boxOffice             14743 non-null   object
#  14  distributor           23001 non-null   object
#  15  soundMix              15917 non-null   object
# dtypes: float64(3), object(13)
# memory usage: 17.5+ MB

# %%
# Merge the datasets based on the correct column names, including the year
df_reviews_with_titles = df_rt.merge(df_rt_movie[['id', 'title', 'releaseDateTheaters']],
                                           on='id',
                                           how='left')

df_reviews_with_titles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1469840 entries, 0 to 1469839
# Data columns (total 13 columns):
#  #   Column               Non-Null Count    Dtype
# ---  ------               --------------    -----
#  0   id                   1469840 non-null  object
#  1   reviewId             1469840 non-null  int64
#  2   creationDate         1469840 non-null  object
#  3   criticName           1469840 non-null  object
#  4   isTopCritic          1469840 non-null  bool
#  5   originalScore        1026937 non-null  object
#  6   reviewState          1469840 non-null  object
#  7   publicatioName       1469840 non-null  object
#  8   reviewText           1399555 non-null  object
#  9   scoreSentiment       1469840 non-null  object
#  10  reviewUrl            1255323 non-null  object
#  11  title                1464073 non-null  object
#  12  releaseDateTheaters  1184070 non-null  object
# dtypes: bool(1), int64(1), object(11)
# memory usage: 136.0+ MB

# %% [markdown]
# ### Step 2: Data Cleaning
#
# - Remove unnecessary columns
#
# - Change data types
#
# - Convert review rating to fit IMDb Ratings

# %%
# Dropping columns
df_reviews_with_titles = df_reviews_with_titles.drop(columns=['id'])
df_reviews_with_titles = df_reviews_with_titles.drop(columns=['reviewId'])
df_reviews_with_titles = df_reviews_with_titles.drop(columns=['isTopCritic'])
df_reviews_with_titles = df_reviews_with_titles.drop(columns=['reviewState'])
df_reviews_with_titles = df_reviews_with_titles.drop(columns=['scoreSentiment'])
df_reviews_with_titles = df_reviews_with_titles.drop(columns=['reviewUrl'])
df_reviews_with_titles = df_reviews_with_titles.drop(columns=['publicatioName'])
df_reviews_with_titles = df_reviews_with_titles.drop(columns=['creationDate'])

# Rename the specified columns in the reviews dataset
df_reviews_with_titles.rename(columns={
    'criticName': 'reviewer_name',
    'originalScore': 'reviewer_rating',
    'reviewText': 'review_text',
    'releaseDateTheaters': 'movie_year_of_release',
    'title': 'movie_title'
}, inplace=True)

# Replace 'Null' with a valid integer or NaN
df_reviews_with_titles['reviewer_rating'] = df_reviews_with_titles['reviewer_rating'].replace('Null', pd.NA)
df_reviews_with_titles['reviewer_rating'] = pd.to_numeric(df_reviews_with_titles['reviewer_rating'], errors='coerce')
df_reviews_with_titles['review_text'] = df_reviews_with_titles['review_text'].replace('', pd.NA)
df_reviews_with_titles['movie_year_of_release'] = pd.to_datetime(df_reviews_with_titles['movie_year_of_release'], errors='coerce')
df_reviews_with_titles = df_reviews_with_titles.dropna()

# Changing the data type 
df_reviews_with_titles['reviewer_name'] = df_reviews_with_titles['reviewer_name'].astype(str)
df_reviews_with_titles['reviewer_rating'] = df_reviews_with_titles['reviewer_rating'].astype(float)
df_reviews_with_titles['review_text'] = df_reviews_with_titles['review_text'].astype(str)

# Extract the year from the datetime object
df_reviews_with_titles['movie_year_of_release'] = df_reviews_with_titles['movie_year_of_release'].dt.year

# %%
def convert_rating(rating):
    # Define a dictionary for letter grades
    letter_grades = {
        'A+': 10.0,
        'A': 10.0,
        'A-': 9.0,
        'B+': 8.0,
        'B': 7.0,
        'B-': 6.0,
        'C+': 5.0,
        'C': 4.0,
        'C-': 3.0,
        'D+': 3.0,
        'D': 2.0,
        'D-': 2.0,
        'F': 1.0,
    }

    if isinstance(rating, str):
        rating = rating.strip().replace("'", "")  # Remove spaces and quotes

        # Check for ratings in the form of x/10
        if '/10' in rating:
            return float(rating.split('/')[0])  # Return just the numeric part

        parts = rating.split('/')

        # Check if it's a fraction (e.g., "3/5", "1/4", "6/100")
        if len(parts) == 2:
            try:
                score = float(parts[0])  # The numerator (e.g., 3 in 3/5)
                max_score = float(parts[1])  # The denominator (e.g., 5 in 3/5)

                if max_score == 5:
                    return score * 2  # Convert /5 to /10, just return the score
                elif max_score == 4:
                    return score * 2.5  # Convert /4 to /10, just return the score
                elif max_score == 100:
                    return score / 10  # Convert /100 to /10, just return the score
            except ValueError:
                return rating  # Return the rating as is if conversion fails

        # Check if the rating is a letter grade
        if rating in letter_grades:
            return letter_grades[rating]  # Return the corresponding numeric value for letter grades

    try:
        # Check if the rating is a float-like string (e.g., "6.0" or "7.5")
        return float(rating)  # If it can be converted to float, return as float
    except ValueError:
        return rating  # Return the rating as is if conversion fails

# Apply the conversion function to the reviewer_rating column
df_reviews_with_titles['reviewer_rating'] = df_reviews_with_titles['reviewer_rating'].apply(convert_rating)

# Display the first few rows to verify the changes
print(df_reviews_with_titles[['reviewer_rating']].head(15))
# Out:
#        reviewer_rating
# 238                7.5
# 471                2.5
# 1375               3.0
# 2655               4.0
# 3788               8.0
# 4552               2.0
# 4723               1.5
# 5869               4.5
# 6910               3.0
# 7547               1.0
# 8160               4.0
# 8625               4.0
# 8827               4.0
# 9062               3.5
# 10130              2.5

# %%
df_reviews_with_titles = df_reviews_with_titles[df_reviews_with_titles['reviewer_rating'] <= 10.0]
df_reviews_with_titles = df_reviews_with_titles[df_reviews_with_titles['reviewer_rating'] >= 0.0]

# %%
# Remove duplicates
df_reviews_with_titles = df_reviews_with_titles.drop_duplicates()
print(df_reviews_with_titles)
# Out:
#                reviewer_name  reviewer_rating  \
# 238      Panos Kotzathanasis              7.5
# 471           Richard Roeper              2.5
# 1375          Kirk Honeycutt              3.0
# 2655             Hope Madden              4.0
# 3788          Kirk Honeycutt              8.0
# ...                      ...              ...
# 1468367        Travis Hopson              3.0
# 1468454          Bob Chipman              3.5
# 1468537          John Hanlon              3.5
# 1468738       Edward Douglas              3.5
# 1468922          Hope Madden              4.5
#
#                                                review_text  \
# 238      Cheng Er seems to have studied Tarantino&#44; ...
# 471      This is a well-intentioned and sometimes quite...
# 1375     A 25-year-old can get away with a sloppy horro...
# 2655     Lamb is an absolutely gorgeous, entirely unusu...
# 3788     Paul Weitz has created a perfect role for Lily...
# ...                                                    ...
# 1468367  The action is excessive, pulse-pounding, and a...
# 1468454  The main comparative takeaway I can give is th...
# 1468537  A well-crafted and patient remake that takes t...
# 1468738  A solid script and cast and a fantastic ending...
# 1468922  She weaves a spontaneous, near-verite style in...
#
#                    movie_title  movie_year_of_release
# 238               Hidden Blade                   2023
# 471                   The DUFF                   2015
# 1375      John Dies at the End                   2013
# 2655                      Lamb                   2021
# 3788                   Grandma                   2015
# ...                        ...                    ...
# 1468367              Ambulance                   2022
# 1468454  The Magnificent Seven                   2016
# 1468537  The Magnificent Seven                   2016
# 1468738  The Magnificent Seven                   2016
# 1468922              Nomadland                   2021
#
# [2832 rows x 5 columns]

# %%
# Join 'movie_title' and 'movie_year_of_release' to create a formatted movie title
df_reviews_with_titles['movie_title'] = df_reviews_with_titles['movie_title'] + ' (' + df_reviews_with_titles['movie_year_of_release'].astype(str) + ')'
print(df_reviews_with_titles)
# Out:
#                reviewer_name  reviewer_rating  \
# 238      Panos Kotzathanasis              7.5
# 471           Richard Roeper              2.5
# 1375          Kirk Honeycutt              3.0
# 2655             Hope Madden              4.0
# 3788          Kirk Honeycutt              8.0
# ...                      ...              ...
# 1468367        Travis Hopson              3.0
# 1468454          Bob Chipman              3.5
# 1468537          John Hanlon              3.5
# 1468738       Edward Douglas              3.5
# 1468922          Hope Madden              4.5
#
#                                                review_text  \
# 238      Cheng Er seems to have studied Tarantino&#44; ...
# 471      This is a well-intentioned and sometimes quite...
# 1375     A 25-year-old can get away with a sloppy horro...
# 2655     Lamb is an absolutely gorgeous, entirely unusu...
# 3788     Paul Weitz has created a perfect role for Lily...
# ...                                                    ...
# 1468367  The action is excessive, pulse-pounding, and a...
# 1468454  The main comparative takeaway I can give is th...
# 1468537  A well-crafted and patient remake that takes t...
# 1468738  A solid script and cast and a fantastic ending...
# 1468922  She weaves a spontaneous, near-verite style in...
#
#                           movie_title  movie_year_of_release
# 238               Hidden Blade (2023)                   2023
# 471                   The DUFF (2015)                   2015
# 1375      John Dies at the End (2013)                   2013
# 2655                      Lamb (2021)                   2021
# 3788                   Grandma (2015)                   2015
# ...                               ...                    ...
# 1468367              Ambulance (2022)                   2022
# 1468454  The Magnificent Seven (2016)                   2016
# 1468537  The Magnificent Seven (2016)                   2016
# 1468738  The Magnificent Seven (2016)                   2016
# 1468922              Nomadland (2021)                   2021
#
# [2832 rows x 5 columns]

# %% [markdown]
# ### Step 3: Check Statistics

# %%
# Descriptive statistics for the date column
movie_year_stats = {
    'count': df_reviews_with_titles['movie_year_of_release'].count(),
    'min': df_reviews_with_titles['movie_year_of_release'].min(),
    'max': df_reviews_with_titles['movie_year_of_release'].max(),
    'mean': df_reviews_with_titles['movie_year_of_release'].mean(),
    'mode': df_reviews_with_titles['movie_year_of_release'].mode()[0],
    'median': df_reviews_with_titles['movie_year_of_release'].median(),
    'sd': df_reviews_with_titles['movie_year_of_release'].std(),
}
print(movie_year_stats)

# Count the number of null values in 'column1'
null_count = df_reviews_with_titles['movie_year_of_release'].isnull().sum()
print(f"Number of null values in 'movie_year_of_release': {null_count}")
# Out:
# {'count': 2832, 'min': 1927, 'max': 2032, 'mean': 2014.5928672316384, 'mode': 2019, 'median': 2017.0, 'sd': 7.998710067279747}
# Number of null values in 'movie_year_of_release': 0

# %%
# Only keep data that is accurate
df_reviews_with_titles = df_reviews_with_titles[df_reviews_with_titles['movie_year_of_release'] <= 2024]

# %%
# Check again
movie_year_stats = {
    'count': df_reviews_with_titles['movie_year_of_release'].count(),
    'min': df_reviews_with_titles['movie_year_of_release'].min(),
    'max': df_reviews_with_titles['movie_year_of_release'].max(),
    'mean': df_reviews_with_titles['movie_year_of_release'].mean(),
    'mode': df_reviews_with_titles['movie_year_of_release'].mode()[0],
    'median': df_reviews_with_titles['movie_year_of_release'].median(),
    'sd': df_reviews_with_titles['movie_year_of_release'].std(),
}
print(movie_year_stats)

# Count the number of null values in 'column1'
null_count = df_reviews_with_titles['movie_year_of_release'].isnull().sum()
print(f"Number of null values in 'movie_year_of_release': {null_count}")
# Out:
# {'count': 2831, 'min': 1927, 'max': 2023, 'mean': 2014.5867184740375, 'mode': 2019, 'median': 2017.0, 'sd': 7.993426199571387}
# Number of null values in 'movie_year_of_release': 0

# %%
# Descriptive statistics for the date column
reviewer_rating_stats = {
    'count': df_reviews_with_titles['reviewer_rating'].count(),
    'min': df_reviews_with_titles['reviewer_rating'].min(),
    'max': df_reviews_with_titles['reviewer_rating'].max(),
    'mean': df_reviews_with_titles['reviewer_rating'].mean(),
    'mode': df_reviews_with_titles['reviewer_rating'].mode()[0],
    'median': df_reviews_with_titles['reviewer_rating'].median(),
    'sd': df_reviews_with_titles['reviewer_rating'].std(),
}
print(reviewer_rating_stats)

# Count the number of null values in 'column1'
null_count = df_reviews_with_titles['reviewer_rating'].isnull().sum()
print(f"Number of null values in 'reviewer_rating': {null_count}")
# Out:
# {'count': 2831, 'min': 0.0, 'max': 10.0, 'mean': 4.2160901742493815, 'mode': 3.5, 'median': 3.5, 'sd': 2.0678806022434246}
# Number of null values in 'reviewer_rating': 0

# %%
# Count the number of null values in 'column1'
null_count = df_reviews_with_titles['review_text'].isnull().sum()
print(f"Number of null values in 'review_text': {null_count}")
# Out:
# Number of null values in 'review_text': 0

# %%
# Create a new DataFrame with review count and average rating for each reviewer
reviewer_stats = df_reviews_with_titles.groupby('reviewer_name').agg(
    review_count=('reviewer_rating', 'size'),
    average_rating=('reviewer_rating', 'mean')
).reset_index()

# Display the new DataFrame
print(reviewer_stats)
# Out:
#          reviewer_name  review_count  average_rating
# 0       Aaron Peterson             1            7.50
# 1         Abbey Bender             1            5.00
# 2        Abhimanyu Das             1            2.50
# 3    Adam A. Donaldson             1            4.50
# 4            Adam Cook             1            2.50
# ..                 ...           ...             ...
# 400       Violet Lucca             1            4.70
# 401        Walter Chaw             2            3.25
# 402      Wesley Lovell             3            3.50
# 403      Willie Waffle             1            1.50
# 404        Ángel Agudo             1            3.50
#
# [405 rows x 3 columns]

# %%
df_reviews_with_titles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2831 entries, 238 to 1468922
# Data columns (total 5 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   reviewer_name          2831 non-null   object
#  1   reviewer_rating        2831 non-null   float64
#  2   review_text            2831 non-null   object
#  3   movie_title            2831 non-null   object
#  4   movie_year_of_release  2831 non-null   int32
# dtypes: float64(1), int32(1), object(3)
# memory usage: 121.6+ KB

# %% [markdown]
# ## IMDb Movies Reviews & Rotten Tomatoes Movies Reviews

# %%
# Concat
df_merge = pd.concat([df_combined, df_reviews_with_titles], ignore_index=True)

df_merge = df_merge.drop_duplicates()
df_merge = df_merge.dropna()

df_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 838279 entries, 0 to 838278
# Data columns (total 5 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   reviewer_name          838279 non-null  object
#  1   reviewer_rating        838279 non-null  float64
#  2   review_text            838279 non-null  object
#  3   movie_title            838279 non-null  object
#  4   movie_year_of_release  838279 non-null  Int64
# dtypes: Int64(1), float64(1), object(3)
# memory usage: 32.8+ MB

# %%
df_merge.head()
# Out:
#    reviewer_name  reviewer_rating  \
# 0  Imme-van-Gorp              7.0
# 1  sonofocelot-1              5.0
# 2        mhodaee              5.0
# 3      fil-nik09              5.0
# 4      DVR_Brale              7.0
#
#                                          review_text  \
# 0  This movie is full of suspense. It makes you g...
# 1  I'll leave this review fairly concise. <br/><b...
# 2  I give the 5/10 out of the credit I owe to the...
# 3  First of all, I must say that I was expecting ...
# 4  I've always loved movies with strong atmospher...
#
#                   movie_title  movie_year_of_release
# 0  10 Cloverfield Lane (2016)                   2016
# 1  10 Cloverfield Lane (2016)                   2016
# 2  10 Cloverfield Lane (2016)                   2016
# 3  10 Cloverfield Lane (2016)                   2016
# 4  10 Cloverfield Lane (2016)                   2016

# %% [markdown]
# ### Check Statistics

# %%
df_merge.isna().sum()
# Out:
# reviewer_name            0
# reviewer_rating          0
# review_text              0
# movie_title              0
# movie_year_of_release    0
# dtype: int64

# %%
# Descriptive statistics for the date column
movie_year_stats = {
    'count': df_merge['movie_year_of_release'].count(),
    'min': df_merge['movie_year_of_release'].min(),
    'max': df_merge['movie_year_of_release'].max(),
    'mean': df_merge['movie_year_of_release'].mean(),
    'mode': df_merge['movie_year_of_release'].mode()[0],
    'median': df_merge['movie_year_of_release'].median(),
    'sd': df_merge['movie_year_of_release'].std(),
}
print(movie_year_stats)

# Count the number of null values in 'column1'
null_count = df_merge['movie_year_of_release'].isnull().sum()
print(f"Number of null values in 'movie_year_of_release': {null_count}")
# Out:
# {'count': 838279, 'min': 1915, 'max': 2023, 'mean': 2005.557547069651, 'mode': 2019, 'median': 2008.0, 'sd': 13.083442531967174}
# Number of null values in 'movie_year_of_release': 0

# %%
# Descriptive statistics for the date column
reviewer_rating_stats = {
    'count': df_merge['reviewer_rating'].count(),
    'min': df_merge['reviewer_rating'].min(),
    'max': df_merge['reviewer_rating'].max(),
    'mean': df_merge['reviewer_rating'].mean(),
    'mode': df_merge['reviewer_rating'].mode()[0],
    'median': df_merge['reviewer_rating'].median(),
    'sd': df_merge['reviewer_rating'].std(),
}
print(reviewer_rating_stats)

# Count the number of null values in 'column1'
null_count = df_merge['reviewer_rating'].isnull().sum()
print(f"Number of null values in 'reviewer_rating': {null_count}")
# Out:
# {'count': 838279, 'min': 0.0, 'max': 10.0, 'mean': 7.167995084313576, 'mode': 10.0, 'median': 8.0, 'sd': 2.882377590304854}
# Number of null values in 'reviewer_rating': 0

# %%
# Count the number of null values in 'column1'
null_count = df_merge['review_text'].isnull().sum()
print(f"Number of null values in 'review_text': {null_count}")
# Out:
# Number of null values in 'review_text': 0

# %% [markdown]
# ### Create Final Data PreProcess Movie Reviews

# %%
# Save the updated DataFrame to a CSV file
df_merge.to_csv('reviews_clean.csv', index=False)

# %%
# Read the CSV file
df = pd.read_csv('reviews_clean.csv')

# Display the first few rows of the dataframe
print(df.head())
# Out:
#    reviewer_name  reviewer_rating  \
# 0  Imme-van-Gorp              7.0
# 1  sonofocelot-1              5.0
# 2        mhodaee              5.0
# 3      fil-nik09              5.0
# 4      DVR_Brale              7.0
#
#                                          review_text  \
# 0  This movie is full of suspense. It makes you g...
# 1  I'll leave this review fairly concise. <br/><b...
# 2  I give the 5/10 out of the credit I owe to the...
# 3  First of all, I must say that I was expecting ...
# 4  I've always loved movies with strong atmospher...
#
#                   movie_title  movie_year_of_release
# 0  10 Cloverfield Lane (2016)                   2016
# 1  10 Cloverfield Lane (2016)                   2016
# 2  10 Cloverfield Lane (2016)                   2016
# 3  10 Cloverfield Lane (2016)                   2016
# 4  10 Cloverfield Lane (2016)                   2016
